# %% [markdown]
# # CRF RNN - Test

# %% [markdown]
# ## Load libraries

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: tensorflow_addons in c:\users\lucas\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (0.19.0)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os

# %%
import os
import numpy as np
import random
import matplotlib.pyplot as plt
from cv2 import imread, resize, cvtColor, COLOR_BGR2RGB

from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras import layers
from tensorflow_addons.layers import CRF
# Out:
# c:\Users\lucas\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Set parameters

# %%
input_dir_train = "train"
input_dir_train_images = os.path.join(input_dir_train, 'JPEGImages')
input_dir_train_annotations = os.path.join(input_dir_train, 'Annotations')

img_size = (320, 320)
batch_size = 16

# %% [markdown]
# ## Create DataGenerator

# %%
class DataGen(keras.utils.Sequence):
    def __init__(self, batch_size, img_size, input_dir_images, input_dir_annotations, mode):
        self.batch_size = batch_size
        self.img_size = img_size
        self.input_dir_images = input_dir_images
        self.input_dir_annotations = input_dir_annotations
        
        self.mode = mode
        self.input_images = self._get_images(input_dir_images)
        self.input_images = self.input_images[:1000] if mode == 'train' else self.input_images[len(self.input_images)//10:]
        self.input_annotations = self._get_images(input_dir_annotations)
        self.input_annotations = self.input_annotations[:1000] if mode == 'train' else self.input_annotations[len(self.input_annotations)//10:]

    def __len__(self):
        return len(self.input_images) // self.batch_size
    
    def _get_images(self, input_dir_images):
        images = []
        for dir in os.listdir(input_dir_images):
            full_path = os.path.join(input_dir_images, dir)
            images += [os.path.join(dir, image) for image in os.listdir(full_path)]
        return images
    
    def _get_image(self, image_path, annotation=False):
        image = imread(image_path)
        image = resize(image, self.img_size)
        image = cvtColor(image, COLOR_BGR2RGB)
        image = image/255
        if annotation:
            image[image!=0] = 1
        return image

    def __getitem__(self, idx):
        i = idx * self.batch_size
        batch_input_img_paths = self.input_images[i : i + self.batch_size]
        X = np.zeros((self.batch_size,) + self.img_size + (3,), dtype="float32")
        Y = X.copy()
        for k, path in enumerate(batch_input_img_paths):
            image_path = os.path.join(self.input_dir_images, path)
            X[k] = self._get_image(image_path)
            
            annotation_path = os.path.join(self.input_dir_annotations, path)
            Y[k] = self._get_image(annotation_path[:-4]+'.png', True)
        return X, Y

# %% [markdown]
# ## Instantiate data Sequences for each split

# %%
train_gen = DataGen(batch_size, img_size, input_dir_train_images, input_dir_train_annotations, 'train')
val_gen = DataGen(batch_size, img_size, input_dir_train_images, input_dir_train_annotations, 'val')
print(len(train_gen), len(val_gen))
# Out:
# 62 5320

# %%
X, Y = val_gen.__getitem__(500)
plt.imshow(X[1])
plt.show()
plt.imshow(Y[1])

# %% [markdown]
# ## Create and instantiate model

# %%
def get_CRF_RNN(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))

    ### [First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [64, 128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual
        
    ### [Second half of the network: upsampling inputs] ###

    for filters in [256, 128, 64, 32]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual
        
    a,b,c,d = x.shape
    x = layers.Reshape((b*c, d))(x)
    decoded_sequence, potentials, sequence_length, chain_kernel = CRF(num_classes+1)(x)
    x = layers.Reshape((1, b, c, -1))(potentials)

    # Add a per-pixel classification layer
    outputs = layers.ConvLSTM2D(3, 3, activation="softmax", padding='same')(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model


# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Build model
model = get_CRF_RNN(img_size, 1)
model.compile(optimizer=keras.optimizers.experimental.RMSprop(), loss="binary_crossentropy")
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\lucas\anaconda3\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 320, 320, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 160, 160, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 160, 160, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 160, 160, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 160, 160, 32  0           ['activation[0][0]']
#                                 )
#
#  separable_conv2d (SeparableCon  (None, 160, 160, 64  2400       ['activation_1[0][0]']
#  v2D)                           )
#
#  batch_normalization_1 (BatchNo  (None, 160, 160, 64  256        ['separable_conv2d[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 160, 160, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  separable_conv2d_1 (SeparableC  (None, 160, 160, 64  4736       ['activation_2[0][0]']
#  onv2D)                         )
#
#  batch_normalization_2 (BatchNo  (None, 160, 160, 64  256        ['separable_conv2d_1[0][0]']
#  rmalization)                   )
#
#  max_pooling2d (MaxPooling2D)   (None, 80, 80, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 80, 80, 64)   2112        ['activation[0][0]']
#
#  add (Add)                      (None, 80, 80, 64)   0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  activation_3 (Activation)      (None, 80, 80, 64)   0           ['add[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 80, 80, 128)  8896       ['activation_3[0][0]']
#  onv2D)
#
#  batch_normalization_3 (BatchNo  (None, 80, 80, 128)  512        ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 80, 80, 128)  0           ['batch_normalization_3[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 80, 80, 128)  17664      ['activation_4[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 80, 80, 128)  512        ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 40, 40, 128)  0          ['batch_normalization_4[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 40, 40, 128)  8320        ['add[0][0]']
#
#  add_1 (Add)                    (None, 40, 40, 128)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  activation_5 (Activation)      (None, 40, 40, 128)  0           ['add_1[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 40, 40, 256)  34176      ['activation_5[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 40, 40, 256)  1024       ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 40, 40, 256)  0           ['batch_normalization_5[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 40, 40, 256)  68096      ['activation_6[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 40, 40, 256)  1024       ['separable_conv2d_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 20, 20, 256)  0          ['batch_normalization_6[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 20, 20, 256)  33024       ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 20, 20, 256)  0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  activation_7 (Activation)      (None, 20, 20, 256)  0           ['add_2[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 20, 20, 256)  590080     ['activation_7[0][0]']
#  ose)
#
#  batch_normalization_7 (BatchNo  (None, 20, 20, 256)  1024       ['conv2d_transpose[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 20, 20, 256)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 20, 20, 256)  590080     ['activation_8[0][0]']
#  spose)
#
#  batch_normalization_8 (BatchNo  (None, 20, 20, 256)  1024       ['conv2d_transpose_1[0][0]']
#  rmalization)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 40, 40, 256)  0          ['add_2[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 40, 40, 256)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 40, 40, 256)  65792       ['up_sampling2d_1[0][0]']
#
#  add_3 (Add)                    (None, 40, 40, 256)  0           ['up_sampling2d[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  activation_9 (Activation)      (None, 40, 40, 256)  0           ['add_3[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 40, 40, 128)  295040     ['activation_9[0][0]']
#  spose)
#
#  batch_normalization_9 (BatchNo  (None, 40, 40, 128)  512        ['conv2d_transpose_2[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (None, 40, 40, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 40, 40, 128)  147584     ['activation_10[0][0]']
#  spose)
#
#  batch_normalization_10 (BatchN  (None, 40, 40, 128)  512        ['conv2d_transpose_3[0][0]']
#  ormalization)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 80, 80, 256)  0          ['add_3[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 80, 80, 128)  0          ['batch_normalization_10[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 80, 80, 128)  32896       ['up_sampling2d_3[0][0]']
#
#  add_4 (Add)                    (None, 80, 80, 128)  0           ['up_sampling2d_2[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  activation_11 (Activation)     (None, 80, 80, 128)  0           ['add_4[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 80, 80, 64)  73792       ['activation_11[0][0]']
#  spose)
#
#  batch_normalization_11 (BatchN  (None, 80, 80, 64)  256         ['conv2d_transpose_4[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 80, 80, 64)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 80, 80, 64)  36928       ['activation_12[0][0]']
#  spose)
#
#  batch_normalization_12 (BatchN  (None, 80, 80, 64)  256         ['conv2d_transpose_5[0][0]']
#  ormalization)
#
#  up_sampling2d_5 (UpSampling2D)  (None, 160, 160, 12  0          ['add_4[0][0]']
#                                 8)
#
#  up_sampling2d_4 (UpSampling2D)  (None, 160, 160, 64  0          ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 160, 160, 64  8256        ['up_sampling2d_5[0][0]']
#                                 )
#
#  add_5 (Add)                    (None, 160, 160, 64  0           ['up_sampling2d_4[0][0]',
#                                 )                                 'conv2d_6[0][0]']
#
#  activation_13 (Activation)     (None, 160, 160, 64  0           ['add_5[0][0]']
#                                 )
#
#  conv2d_transpose_6 (Conv2DTran  (None, 160, 160, 32  18464      ['activation_13[0][0]']
#  spose)                         )
#
#  batch_normalization_13 (BatchN  (None, 160, 160, 32  128        ['conv2d_transpose_6[0][0]']
#  ormalization)                  )
#
#  activation_14 (Activation)     (None, 160, 160, 32  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 160, 160, 32  9248       ['activation_14[0][0]']
#  spose)                         )
#
#  batch_normalization_14 (BatchN  (None, 160, 160, 32  128        ['conv2d_transpose_7[0][0]']
#  ormalization)                  )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 320, 320, 64  0          ['add_5[0][0]']
#                                 )
#
#  up_sampling2d_6 (UpSampling2D)  (None, 320, 320, 32  0          ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 320, 320, 32  2080        ['up_sampling2d_7[0][0]']
#                                 )
#
#  add_6 (Add)                    (None, 320, 320, 32  0           ['up_sampling2d_6[0][0]',
#                                 )                                 'conv2d_7[0][0]']
#
#  reshape (Reshape)              (None, 102400, 32)   0           ['add_6[0][0]']
#
#  crf (CRF)                      [(None, 102400),     74          ['reshape[0][0]']
#                                  (None, 102400, 2),
#                                  (None,),
#                                  (2, 2)]
#
#  reshape_1 (Reshape)            (None, 1, 320, 320,  0           ['crf[0][1]']
#                                  2)
#
#  conv_lstm2d (ConvLSTM2D)       (None, 320, 320, 3)  552         ['reshape_1[0][0]']
#
# ==================================================================================================
# Total params: 2,058,738
# Trainable params: 2,054,962
# Non-trainable params: 3,776
# __________________________________________________________________________________________________

# %% [markdown]
# ## Display val dataset exemples

# %%
model.load_weights("youtube_.h5")

# %%
image_index = 1662
preds = model.predict(val_gen[image_index][0])

image = val_gen[image_index][0][0]
pred = preds[0]
image_binarised = image.copy()
image_binarised[pred > 0.2] = 1
annotation=val_gen[image_index][1][0]

plt.imshow(image)
plt.show()
plt.imshow(image_binarised)
plt.show()
plt.imshow(annotation)
plt.show()
# Out:
# 1/1 [==============================] - 4s 4s/step
